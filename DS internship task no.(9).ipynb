# %%
#Programmer name: Rachana Shivarkar
#College name: Keystone School of Engineering
#Class: TE (B)
#Roll no: 37
#Assigned task no: 9

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("titanic_data.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                Surname    Name   Sex  Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0    1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0    1
# 2                               Heikkinen, Miss. Laina  female  26.0    0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    1
# 4                             Allen, Mr. William Henry    male  35.0    0
# ..                                                 ...     ...   ...  ...
# ...

# %% [markdown]
#  Note: 'Name' column has info of 'Sex'.
#
#  1.Print the names of all female passengers who survived

# %%
fs = df[(df['Name'] == 'female') & (df['Survived'] == 1)]

fs['Surname']
# Out:
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 8      Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                    Nasser, Mrs. Nicholas (Adele Achem)
#                              ...
# 874                Abelson, Mrs. Samuel (Hannah Wizosky)
# 875                     Najib, Miss. Adele Kiamie "Jane"
# 879        Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 880         Shelley, Mrs. William (Imanita Parrish Hall)
# 887                         Graham, Miss. Margaret Edith
# Name: Surname, Length: 233, dtype: object

# %% [markdown]
# 2. Sort and print the names of passengers who were children (age less than 18) and survived.

# %%
cs = df[(df['Age'] < 18) & (df['Survived'] == 1)]
scs = cs.sort_values(by='Surname')
scs['Surname']
# Out:
# 279                Abbott, Mrs. Stanton (Rosa Hunt)
# 874           Abelson, Mrs. Samuel (Hannah Wizosky)
# 855                      Aks, Mrs. Sam (Leah Rosen)
# 207                     Albimona, Mr. Nassef Cassem
# 730                   Allen, Miss. Elisabeth Walton
#                            ...
# 55                                Woolner, Mr. Hugh
# 830         Yasbeck, Mrs. Antoni (Selini Alexander)
# 325                        Young, Miss. Marie Grice
# 559    de Messemaeker, Mrs. Guillaume Joseph (Emma)
# 286                         de Mulder, Mr. Theodore
# Name: Surname, Length: 342, dtype: object

# %% [markdown]
# Note:'Cabin' column has info about 'Embarked'
#
# 3.How many passengers embarked from Southampton

# %%
sp = df[df['Cabin'] == 'S']
sp
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# ..           ...       ...     ...
# 883          884         0       2
# 884          885         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
#
#                                           Surname    Name   Sex  Age  SibSp  \
# 0                         Braund, Mr. Owen Harris    male  22.0    1      0
# 2                          Heikkinen, Miss. Laina  female  26.0    0      0
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    1      0
# 4                        Allen, Mr. William Henry    male  35.0    0      0
# 6                         McCarthy, Mr. Timothy J    male  54.0    0      0
# ..                                            ...     ...   ...  ...    ...
# ...

# %%
print("\n Number of passengers embarked from Southampton is:",len(sp))
# Out:
#  Number of passengers embarked from Southampton is: 644

# %% [markdown]
# 4.Print the name and age of passengers (non-null values) who embarked
#  from Cherbourg.

# %%
cb=df[df['Cabin']=='C']
cb
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 9             10         1       2
# 19            20         1       3
# 26            27         0       3
# 30            31         0       1
# ..           ...       ...     ...
# 866          867         1       2
# 874          875         1       2
# 875          876         1       3
# 879          880         1       1
# 889          890         1       1
#
#                                                Surname    Name   Sex  Age  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0    1
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0    1
# 19                             Masselmani, Mrs. Fatima  female   NaN    0
# 26                             Emir, Mr. Farred Chehab    male   NaN    0
# 30                            Uruchurtu, Don. Manuel E    male  40.0    0
# ..                                                 ...     ...   ...  ...
# ...

# %%
print("\n Names and age of passengers who embarked from Cherbourg")
df[['Surname','Sex']].dropna()
# Out:
#  Names and age of passengers who embarked from Cherbourg
#                                                Surname   Sex
# 0                              Braund, Mr. Owen Harris  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                               Heikkinen, Miss. Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                             Allen, Mr. William Henry  35.0
# ..                                                 ...   ...
# 885               Rice, Mrs. William (Margaret Norton)  39.0
# 886                              Montvila, Rev. Juozas  27.0
# 887                       Graham, Miss. Margaret Edith  19.0
# 889                              Behr, Mr. Karl Howell  26.0
# 890                                Dooley, Mr. Patrick  32.0
#
# [714 rows x 2 columns]

# %% [markdown]
# Note: In dataset 'Age' column has information about siblings and spouses.
#
# 5. How many passengers had siblings or spouses aboard?

# %%
sbsp = df[df['Age'] > 0]
print("\n Number of passengers who has siblings and spouses abroad is:",len(sbsp))
# Out:
#  Number of passengers who has siblings and spouses abroad is: 283

# %% [markdown]
#  6.How many passengers paid a fare greater than $100?

# %%
pf=df[df['Ticket']>100]
print("\n Number of passengers who paid fare greater than $100:",len(pf))
# Out:
#  Number of passengers who paid fare greater than $100: 53

# %% [markdown]
#  7.Print the names of passengers with the title "Dr."

# %%
dp = df[df['Surname'].str.contains('Dr\.')]
print("\nNames of passengers with the title 'Dr.'")
print(dp['Surname'])
# Out:
# Names of passengers with the title 'Dr.'
# 245      Minahan, Dr. William Edward
# 317             Moraweck, Dr. Ernest
# 398                 Pain, Dr. Alfred
# 632        Stahelin-Maeglin, Dr. Max
# 660    Frauenthal, Dr. Henry William
# 766        Brewe, Dr. Arthur Jackson
# 796      Leader, Dr. Alice (Farnham)
# Name: Surname, dtype: object

# %% [markdown]
# Note: In dataset the columns is missing for this question.
#
# 8.Print the names of passengers who were part of the crew.

# %% [markdown]
# Note: In dataset the columns is missing for this question.
#
# 9.Find information about passengers who boarded lifeboats and survived

# %% [markdown]
#  10.Plot the count of passengers by their embarkation port
#
#  Note: 'Cabin' column has 'Embarked' info.

# %%
import matplotlib.pyplot as plt

ec =df['Cabin'].value_counts()
ec.plot(kind='bar', color='pink')
plt.title('Count of Passengers by Embarkation Port')
plt.xlabel('Embarkation Port')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()
